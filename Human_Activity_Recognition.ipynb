# %% [markdown]
# # HumanActivityRecognition
#
# <br>
#
#
# This project is to build a model that predicts the human activities such as Walking, Walking_Upstairs, Walking_Downstairs, Sitting, Standing or Laying.
#
# This dataset is collected from 30 persons(referred as subjects in this dataset), performing different activities with a smartphone to their waists. The data is recorded with the help of sensors (accelerometer and Gyroscope) in that smartphone. This experiment was video recorded to label the data manually.

# %% [markdown]
# ## Train and test data were saperated
#  - The readings from ___70%___ of the volunteers were taken as ___trianing data___ and remaining ___30%___ subjects recordings were taken for ___test data___
#  - 21 Persons data for training & 9 Person data for Testing

# %% [markdown]
# ## Data
#
# * All the data is present in 'UCI_HAR_dataset/' folder in present working directory.
#      - Feature names are present in 'UCI_HAR_dataset/features.txt'
#      - ___Train Data___
#          - 'UCI_HAR_dataset/train/X_train.txt'
#          - 'UCI_HAR_dataset/train/subject_train.txt'
#          - 'UCI_HAR_dataset/train/y_train.txt'
#      - ___Test Data___
#          - 'UCI_HAR_dataset/test/X_test.txt'
#          - 'UCI_HAR_dataset/test/subject_test.txt'
#          - 'UCI_HAR_dataset/test/y_test.txt'

# %% [markdown]
# ## Quick overview of the dataset :
#
# * Accelerometer and Gyroscope readings are taken from 30 volunteers(referred as subjects) while performing the following 6 Activities.
#
#     1. Walking
#     2. WalkingUpstairs
#     3. WalkingDownstairs
#     4. Standing
#     5. Sitting
#     6. Lying.
#
#
# * Readings are divided into a window of 2.56 seconds with 50% overlapping.
#
# * Accelerometer readings are divided into gravity acceleration and body acceleration readings,
#   which has x,y and z components each.
#
# * Gyroscope readings are the measure of angular velocities which has x,y and z components.
#
# * Jerk signals are calculated for BodyAcceleration readings.
#
# * Fourier Transforms are made on the above time readings to obtain frequency readings.
#
# * Now, on all the base signal readings., mean, max, mad, sma, arcoefficient, engerybands,entropy etc., are calculated for each window.
#
# * We get a feature vector of 561 features and these features are given in the dataset.
#
# * Each window of readings is a datapoint of 561 features.

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Users\Shivanshu\Anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\Shivanshu\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# C:\Users\Shivanshu\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
# get the features from the file features.txt
features = list()
with open('UCI_HAR_Dataset/features.txt') as f:
    for line in f.readlines():
        features.append(line.split()[1])
print('Total No. of Features: {}'.format(len(features)))
# Out:
# Total No. of Features: 561

# %% [markdown]
# ### Getting Data (Train)

# %%
X_train = pd.read_csv('UCI_HAR_dataset/train/X_train.txt', delim_whitespace=True, header=None)
X_train.columns = features

# %%
# add subject column to the dataframe (Person ID)
X_train['subject'] = pd.read_csv('UCI_HAR_dataset/train/subject_train.txt', header=None, squeeze=True)

# %%
y_train = pd.read_csv('UCI_HAR_dataset/train/y_train.txt', names=['Activity'], squeeze=True)
y_train_labels = y_train.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',4:'SITTING', 5:'STANDING',6:'LAYING'})

# %%
X_train['Activity'] = y_train
X_train['ActivityName'] = y_train_labels
X_train.sample()
# Out:
#       tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 3160            0.21117           0.003512          -0.091313
#
#       tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 3160          -0.95757          -0.91594         -0.945122          -0.96056
#
#       tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# 3160         -0.933804         -0.960796         -0.925466  ...
#
#       angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 3160                     0.056977                              0.915567
#
#       angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 3160                          0.000662                             -0.176409
#
#       angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 3160              0.457423              0.407301             -0.787467
#
#       subject  Activity  ActivityName
# 3160       16         6        LAYING
#
# [1 rows x 564 columns]

# %%
X_train.shape
# Out:
# (7352, 564)

# %% [markdown]
# ### Getting Data (Test)

# %%
# get the data from txt files to pandas dataffame
X_test = pd.read_csv('UCI_HAR_dataset/test/X_test.txt', delim_whitespace=True, header=None)
X_test.columns = features

# add subject column to the dataframe
X_test['subject'] = pd.read_csv('UCI_HAR_dataset/test/subject_test.txt', header=None, squeeze=True)

# get y labels from the txt file
y_test = pd.read_csv('UCI_HAR_dataset/test/y_test.txt', names=['Activity'], squeeze=True)
y_test_labels = y_test.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})


# put all columns in a single dataframe
X_test['Activity'] = y_test
X_test['ActivityName'] = y_test_labels
X_test.sample()
# Out:
#      tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# 912           0.277531          -0.005264          -0.087587
#
#      tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# 912         -0.989346         -0.934047         -0.976196         -0.990888
#
#      tBodyAcc-mad()-Y  tBodyAcc-mad()-Z  tBodyAcc-max()-X  ...  \
# 912         -0.942901         -0.974836         -0.935133  ...
#
#      angle(tBodyAccMean,gravity)  angle(tBodyAccJerkMean),gravityMean)  \
# 912                     0.056411                             -0.053506
#
#      angle(tBodyGyroMean,gravityMean)  angle(tBodyGyroJerkMean,gravityMean)  \
# 912                         -0.302205                              0.697786
#
#      angle(X,gravityMean)  angle(Y,gravityMean)  angle(Z,gravityMean)  \
# 912             -0.808676              0.223474             -0.025884
#
#      subject  Activity  ActivityName
# 912       10         5      STANDING
#
# [1 rows x 564 columns]

# %%
X_test.shape
# Out:
# (2947, 564)

# %% [markdown]
# ### Checking Data

# %%
# Checking for Duplicates
print('No of duplicates in train: {}'.format(sum(X_train.duplicated())))
print('No of duplicates in test : {}'.format(sum(X_test.duplicated())))
# Out:
# No of duplicates in train: 0
# No of duplicates in test : 0

# %%
# Checking for NaN/NULL values
print('We have {} NaN/Null values in train'.format(X_train.isnull().values.sum()))
print('We have {} NaN/Null values in test'.format(X_test.isnull().values.sum()))
# Out:
# We have 0 NaN/Null values in train
# We have 0 NaN/Null values in test

# %%
# Checking for Data Imbalance
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
plt.rcParams['font.family'] = 'Dejavu Sans'

plt.figure(figsize=(16,8))
plt.title('Data provided by each user', fontsize=20)
sns.countplot(x='subject',hue='ActivityName', data = X_train)
plt.show()

# %% [markdown]
# - We have apprx. same number of reading from all subjects

# %%
plt.title('No of Datapoints per Activity', fontsize=15)
sns.countplot(X_train.ActivityName)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Modifying Feature names

# %%
columns = X_train.columns

# Removing '()' from column names
columns = columns.str.replace('[()]','')
columns = columns.str.replace('[-]', '')
columns = columns.str.replace('[,]','')

X_train.columns = columns
X_test.columns = columns

X_test.head()
# Out:
#    tBodyAccmeanX  tBodyAccmeanY  tBodyAccmeanZ  tBodyAccstdX  tBodyAccstdY  \
# 0       0.257178      -0.023285      -0.014654     -0.938404     -0.920091
# 1       0.286027      -0.013163      -0.119083     -0.975415     -0.967458
# 2       0.275485      -0.026050      -0.118152     -0.993819     -0.969926
# 3       0.270298      -0.032614      -0.117520     -0.994743     -0.973268
# 4       0.274833      -0.027848      -0.129527     -0.993852     -0.967445
#
#    tBodyAccstdZ  tBodyAccmadX  tBodyAccmadY  tBodyAccmadZ  tBodyAccmaxX  ...  \
# 0     -0.667683     -0.952501     -0.925249     -0.674302     -0.894088  ...
# 1     -0.944958     -0.986799     -0.968401     -0.945823     -0.894088  ...
# 2     -0.962748     -0.994403     -0.970735     -0.963483     -0.939260  ...
# 3     -0.967091     -0.995274     -0.974471     -0.968897     -0.938610  ...
# 4     -0.978295     -0.994111     -0.965953     -0.977346     -0.938610  ...
#
#    angletBodyAccMeangravity  angletBodyAccJerkMeangravityMean  \
# 0                  0.006462                          0.162920
# 1                 -0.083495                          0.017500
# 2                 -0.034956                          0.202302
# 3                 -0.017067                          0.154438
# 4                 -0.002223                         -0.040046
#
#    angletBodyGyroMeangravityMean  angletBodyGyroJerkMeangravityMean  \
# 0                      -0.825886                           0.271151
# 1                      -0.434375                           0.920593
# 2                       0.064103                           0.145068
# 3                       0.340134                           0.296407
# 4                       0.736715                          -0.118545
#
#    angleXgravityMean  angleYgravityMean  angleZgravityMean  subject  Activity  \
# 0          -0.720009           0.276801          -0.057978        2         5
# 1          -0.698091           0.281343          -0.083898        2         5
# 2          -0.702771           0.280083          -0.079346        2         5
# 3          -0.698954           0.284114          -0.077108        2         5
# 4          -0.692245           0.290722          -0.073857        2         5
#
#    ActivityName
# 0      STANDING
# 1      STANDING
# 2      STANDING
# 3      STANDING
# 4      STANDING
#
# [5 rows x 564 columns]

# %% [markdown]
# ## Save DataFrame to a CSV file

# %%
X_train.to_csv('UCI_HAR_Dataset/csv_files/train.csv', index=False)
X_test.to_csv('UCI_HAR_Dataset/csv_files/test.csv', index=False)

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# #### Feature Engineering from Domain Knowledge

# %% [markdown]
# - In Static activities (Sit, Stand, Lie Down) motion information will be useful
# - In Dynamic activities (Walking, Walkin Upstairs, Walking Downstairs) motion information will be useful

# %%
sns.set_palette("Set1", desat=0.80)
facetgrid = sns.FacetGrid(X_train, hue='ActivityName', size=6,aspect=2)
facetgrid.map(sns.distplot,'tBodyAccMagmean', hist=False).add_legend()
plt.show()

# %% [markdown]
# -  Plotting Box plots of Activity

# %%
plt.figure(figsize=(7,7))
sns.boxplot(x='ActivityName', y='tBodyAccMagmean',data=X_train, showfliers=False, saturation=1)
plt.ylabel('Acceleration Magnitude mean')
plt.axhline(y=-0.7, xmin=0.1, xmax=0.9,dashes=(5,5), c='g')
plt.axhline(y=-0.05, xmin=0.4, dashes=(5,5), c='m')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Observations</br>
#
# - If tBodyAccMagmean > 0 then the Activity is Walking_Downstairs </br>
# - If tBodyAccMagmean < -0.8 the Activity is one of the Static Activity like (Standing, Sittin, Laying)</br>

# %%
sns.boxplot(x='ActivityName', y='angleXgravityMean', data=X_train)
plt.axhline(y=0.08, xmin=0.1, xmax=0.9,c='m',dashes=(5,3))
plt.title('Angle between X-axis and Gravity_mean', fontsize=15)
plt.xticks(rotation = 40)
plt.show()

# %% [markdown]
# #### Observations
# - If angleXgravityMean > 0 then Activity is Laying

# %% [markdown]
# # Applying t-sne on the Data

# %%
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# performs t-sne with different perplexity values and their repective plots.
def perform_tsne(X_data, y_data, perplexities, n_iter=1000, img_name_prefix='t-sne'):
        
    for index,perplexity in enumerate(perplexities):
        # perform t-sne
        print('\nperforming tsne with perplexity {} and with {} iterations at max'.format(perplexity, n_iter))
        X_reduced = TSNE(verbose=2, perplexity=perplexity).fit_transform(X_data)
        print('Done..')
        
        # prepare the data for seaborn         
        print('Creating plot for this t-sne visualization..')
        df = pd.DataFrame({'x':X_reduced[:,0], 'y':X_reduced[:,1] ,'label':y_data})
        
        # draw the plot in appropriate place in the grid
        sns.lmplot(data=df, x='x', y='y', hue='label', fit_reg=False, size=8,\
                   palette="Set1",markers=['^','v','s','o', '1','2'])
        plt.title("perplexity : {} and max_iter : {}".format(perplexity, n_iter))
        img_name = img_name_prefix + '_perp_{}_iter_{}.png'.format(perplexity, n_iter)
        print('saving this plot as image in present working directory...')
        plt.savefig(img_name)
        plt.show()
        print('Done')

# %%
X_pre_tsne = X_train.drop(['subject', 'Activity','ActivityName'], axis=1)
y_pre_tsne = X_train['ActivityName']
perform_tsne(X_data = X_pre_tsne,y_data=y_pre_tsne, perplexities =[2,5,10,20,50])
# Out:
# performing tsne with perplexity 2 and with 1000 iterations at max
# [t-SNE] Computing 7 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.005s...
# [t-SNE] Computed neighbors for 7352 samples in 1.233s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.635854
# [t-SNE] Computed conditional probabilities in 0.028s
# [t-SNE] Iteration 50: error = 124.6251068, gradient norm = 0.0255642 (50 iterations in 1.452s)
# [t-SNE] Iteration 100: error = 107.0028915, gradient norm = 0.0272640 (50 iterations in 0.866s)
# [t-SNE] Iteration 150: error = 100.7526855, gradient norm = 0.0181896 (50 iterations in 0.759s)
# [t-SNE] Iteration 200: error = 97.3550186, gradient norm = 0.0148602 (50 iterations in 0.758s)
# [t-SNE] Iteration 250: error = 95.0635757, gradient norm = 0.0147274 (50 iterations in 0.813s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 95.063576
# [t-SNE] Iteration 300: error = 4.1106758, gradient norm = 0.0015568 (50 iterations in 0.764s)
# [t-SNE] Iteration 350: error = 3.2060966, gradient norm = 0.0010099 (50 iterations in 0.756s)
# [t-SNE] Iteration 400: error = 2.7771502, gradient norm = 0.0007136 (50 iterations in 0.724s)
# [t-SNE] Iteration 450: error = 2.5137639, gradient norm = 0.0005634 (50 iterations in 0.696s)
# [t-SNE] Iteration 500: error = 2.3310845, gradient norm = 0.0004768 (50 iterations in 0.698s)
# [t-SNE] Iteration 550: error = 2.1932654, gradient norm = 0.0004124 (50 iterations in 0.705s)
# [t-SNE] Iteration 600: error = 2.0839088, gradient norm = 0.0003691 (50 iterations in 0.707s)
# [t-SNE] Iteration 650: error = 1.9942974, gradient norm = 0.0003300 (50 iterations in 0.708s)
# [t-SNE] Iteration 700: error = 1.9187083, gradient norm = 0.0003022 (50 iterations in 0.715s)
# [t-SNE] Iteration 750: error = 1.8537123, gradient norm = 0.0002738 (50 iterations in 0.711s)
# [t-SNE] Iteration 800: error = 1.7968241, gradient norm = 0.0002577 (50 iterations in 0.713s)
# [t-SNE] Iteration 850: error = 1.7468234, gradient norm = 0.0002421 (50 iterations in 0.717s)
# [t-SNE] Iteration 900: error = 1.7022111, gradient norm = 0.0002236 (50 iterations in 0.731s)
# [t-SNE] Iteration 950: error = 1.6620622, gradient norm = 0.0002100 (50 iterations in 0.706s)
# [t-SNE] Iteration 1000: error = 1.6257683, gradient norm = 0.0001993 (50 iterations in 0.734s)
# [t-SNE] KL divergence after 1000 iterations: 1.625768
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 5 and with 1000 iterations at max
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.011s...
# [t-SNE] Computed neighbors for 7352 samples in 1.229s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 0.961265
# [t-SNE] Computed conditional probabilities in 0.041s
# [t-SNE] Iteration 50: error = 114.1790466, gradient norm = 0.0198017 (50 iterations in 0.940s)
# [t-SNE] Iteration 100: error = 97.8815155, gradient norm = 0.0158469 (50 iterations in 0.804s)
# [t-SNE] Iteration 150: error = 93.3130341, gradient norm = 0.0125736 (50 iterations in 0.783s)
# [t-SNE] Iteration 200: error = 91.2480545, gradient norm = 0.0064775 (50 iterations in 0.746s)
# [t-SNE] Iteration 250: error = 90.0350952, gradient norm = 0.0050571 (50 iterations in 0.742s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 90.035095
# [t-SNE] Iteration 300: error = 3.5745909, gradient norm = 0.0014614 (50 iterations in 0.685s)
# [t-SNE] Iteration 350: error = 2.8145494, gradient norm = 0.0007466 (50 iterations in 0.736s)
# [t-SNE] Iteration 400: error = 2.4327710, gradient norm = 0.0005252 (50 iterations in 0.773s)
# [t-SNE] Iteration 450: error = 2.2145209, gradient norm = 0.0004014 (50 iterations in 0.739s)
# [t-SNE] Iteration 500: error = 2.0695097, gradient norm = 0.0003310 (50 iterations in 0.745s)
# [t-SNE] Iteration 550: error = 1.9638621, gradient norm = 0.0002818 (50 iterations in 0.749s)
# [t-SNE] Iteration 600: error = 1.8825853, gradient norm = 0.0002457 (50 iterations in 0.768s)
# [t-SNE] Iteration 650: error = 1.8175223, gradient norm = 0.0002201 (50 iterations in 0.760s)
# [t-SNE] Iteration 700: error = 1.7639616, gradient norm = 0.0001960 (50 iterations in 0.787s)
# [t-SNE] Iteration 750: error = 1.7187767, gradient norm = 0.0001782 (50 iterations in 0.756s)
# [t-SNE] Iteration 800: error = 1.6797618, gradient norm = 0.0001656 (50 iterations in 0.752s)
# [t-SNE] Iteration 850: error = 1.6458094, gradient norm = 0.0001515 (50 iterations in 0.735s)
# [t-SNE] Iteration 900: error = 1.6159121, gradient norm = 0.0001413 (50 iterations in 0.777s)
# [t-SNE] Iteration 950: error = 1.5894301, gradient norm = 0.0001332 (50 iterations in 0.772s)
# [t-SNE] Iteration 1000: error = 1.5655786, gradient norm = 0.0001269 (50 iterations in 0.939s)
# [t-SNE] KL divergence after 1000 iterations: 1.565579
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 10 and with 1000 iterations at max
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.005s...
# [t-SNE] Computed neighbors for 7352 samples in 1.236s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.133828
# [t-SNE] Computed conditional probabilities in 0.089s
# [t-SNE] Iteration 50: error = 105.8823090, gradient norm = 0.0166527 (50 iterations in 1.429s)
# [t-SNE] Iteration 100: error = 91.1330795, gradient norm = 0.0109416 (50 iterations in 0.961s)
# [t-SNE] Iteration 150: error = 87.5192413, gradient norm = 0.0069632 (50 iterations in 0.868s)
# [t-SNE] Iteration 200: error = 86.2183762, gradient norm = 0.0046323 (50 iterations in 0.838s)
# [t-SNE] Iteration 250: error = 85.5093536, gradient norm = 0.0034729 (50 iterations in 0.793s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 85.509354
# [t-SNE] Iteration 300: error = 3.1479571, gradient norm = 0.0013956 (50 iterations in 0.809s)
# [t-SNE] Iteration 350: error = 2.5008268, gradient norm = 0.0006521 (50 iterations in 0.755s)
# [t-SNE] Iteration 400: error = 2.1805809, gradient norm = 0.0004236 (50 iterations in 0.786s)
# [t-SNE] Iteration 450: error = 1.9954734, gradient norm = 0.0003130 (50 iterations in 0.801s)
# [t-SNE] Iteration 500: error = 1.8765774, gradient norm = 0.0002532 (50 iterations in 0.811s)
# [t-SNE] Iteration 550: error = 1.7928648, gradient norm = 0.0002101 (50 iterations in 0.794s)
# [t-SNE] Iteration 600: error = 1.7300854, gradient norm = 0.0001817 (50 iterations in 0.766s)
# [t-SNE] Iteration 650: error = 1.6811124, gradient norm = 0.0001595 (50 iterations in 0.779s)
# [t-SNE] Iteration 700: error = 1.6412631, gradient norm = 0.0001443 (50 iterations in 0.770s)
# [t-SNE] Iteration 750: error = 1.6083950, gradient norm = 0.0001310 (50 iterations in 0.775s)
# [t-SNE] Iteration 800: error = 1.5810688, gradient norm = 0.0001191 (50 iterations in 0.772s)
# [t-SNE] Iteration 850: error = 1.5574346, gradient norm = 0.0001113 (50 iterations in 0.773s)
# [t-SNE] Iteration 900: error = 1.5372591, gradient norm = 0.0001031 (50 iterations in 0.805s)
# [t-SNE] Iteration 950: error = 1.5196576, gradient norm = 0.0000974 (50 iterations in 0.806s)
# [t-SNE] Iteration 1000: error = 1.5042048, gradient norm = 0.0000921 (50 iterations in 0.800s)
# [t-SNE] KL divergence after 1000 iterations: 1.504205
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 20 and with 1000 iterations at max
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.005s...
# [t-SNE] Computed neighbors for 7352 samples in 1.236s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.274335
# [t-SNE] Computed conditional probabilities in 0.147s
# [t-SNE] Iteration 50: error = 97.5027084, gradient norm = 0.0205967 (50 iterations in 1.058s)
# [t-SNE] Iteration 100: error = 84.1175461, gradient norm = 0.0058503 (50 iterations in 0.948s)
# [t-SNE] Iteration 150: error = 82.0242691, gradient norm = 0.0043182 (50 iterations in 0.906s)
# [t-SNE] Iteration 200: error = 81.1979294, gradient norm = 0.0023373 (50 iterations in 0.864s)
# [t-SNE] Iteration 250: error = 80.8027115, gradient norm = 0.0029088 (50 iterations in 0.869s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 80.802711
# [t-SNE] Iteration 300: error = 2.6974640, gradient norm = 0.0012992 (50 iterations in 0.868s)
# [t-SNE] Iteration 350: error = 2.1639643, gradient norm = 0.0005778 (50 iterations in 0.833s)
# [t-SNE] Iteration 400: error = 1.9142902, gradient norm = 0.0003505 (50 iterations in 0.831s)
# [t-SNE] Iteration 450: error = 1.7682304, gradient norm = 0.0002485 (50 iterations in 0.829s)
# [t-SNE] Iteration 500: error = 1.6738927, gradient norm = 0.0001925 (50 iterations in 0.864s)
# [t-SNE] Iteration 550: error = 1.6095092, gradient norm = 0.0001581 (50 iterations in 0.891s)
# [t-SNE] Iteration 600: error = 1.5627078, gradient norm = 0.0001342 (50 iterations in 0.859s)
# [t-SNE] Iteration 650: error = 1.5272552, gradient norm = 0.0001186 (50 iterations in 0.853s)
# [t-SNE] Iteration 700: error = 1.4999213, gradient norm = 0.0001048 (50 iterations in 0.833s)
# [t-SNE] Iteration 750: error = 1.4782143, gradient norm = 0.0000963 (50 iterations in 0.837s)
# [t-SNE] Iteration 800: error = 1.4605765, gradient norm = 0.0000887 (50 iterations in 0.839s)
# [t-SNE] Iteration 850: error = 1.4458055, gradient norm = 0.0000829 (50 iterations in 0.827s)
# [t-SNE] Iteration 900: error = 1.4335043, gradient norm = 0.0000782 (50 iterations in 0.835s)
# [t-SNE] Iteration 950: error = 1.4231478, gradient norm = 0.0000746 (50 iterations in 0.830s)
# [t-SNE] Iteration 1000: error = 1.4144526, gradient norm = 0.0000742 (50 iterations in 0.856s)
# [t-SNE] KL divergence after 1000 iterations: 1.414453
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 50 and with 1000 iterations at max
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 7352 samples in 0.005s...
# [t-SNE] Computed neighbors for 7352 samples in 1.309s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 7352
# [t-SNE] Computed conditional probabilities for sample 2000 / 7352
# [t-SNE] Computed conditional probabilities for sample 3000 / 7352
# [t-SNE] Computed conditional probabilities for sample 4000 / 7352
# [t-SNE] Computed conditional probabilities for sample 5000 / 7352
# [t-SNE] Computed conditional probabilities for sample 6000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7000 / 7352
# [t-SNE] Computed conditional probabilities for sample 7352 / 7352
# [t-SNE] Mean sigma: 1.437672
# [t-SNE] Computed conditional probabilities in 0.382s
# [t-SNE] Iteration 50: error = 84.7060013, gradient norm = 0.0359916 (50 iterations in 1.247s)
# [t-SNE] Iteration 100: error = 75.4724350, gradient norm = 0.0037978 (50 iterations in 1.168s)
# [t-SNE] Iteration 150: error = 74.6186218, gradient norm = 0.0033588 (50 iterations in 1.153s)
# [t-SNE] Iteration 200: error = 74.2871857, gradient norm = 0.0015143 (50 iterations in 1.181s)
# [t-SNE] Iteration 250: error = 74.1157074, gradient norm = 0.0011258 (50 iterations in 1.147s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.115707
# [t-SNE] Iteration 300: error = 2.1509480, gradient norm = 0.0011771 (50 iterations in 1.117s)
# [t-SNE] Iteration 350: error = 1.7537736, gradient norm = 0.0004852 (50 iterations in 1.146s)
# [t-SNE] Iteration 400: error = 1.5850236, gradient norm = 0.0002797 (50 iterations in 1.111s)
# [t-SNE] Iteration 450: error = 1.4911383, gradient norm = 0.0001893 (50 iterations in 1.145s)
# [t-SNE] Iteration 500: error = 1.4314389, gradient norm = 0.0001397 (50 iterations in 1.109s)
# [t-SNE] Iteration 550: error = 1.3903563, gradient norm = 0.0001135 (50 iterations in 1.169s)
# [t-SNE] Iteration 600: error = 1.3609619, gradient norm = 0.0000948 (50 iterations in 1.095s)
# [t-SNE] Iteration 650: error = 1.3398358, gradient norm = 0.0000834 (50 iterations in 1.165s)
# [t-SNE] Iteration 700: error = 1.3248385, gradient norm = 0.0000746 (50 iterations in 1.108s)
# [t-SNE] Iteration 750: error = 1.3135304, gradient norm = 0.0000708 (50 iterations in 1.149s)
# [t-SNE] Iteration 800: error = 1.3047538, gradient norm = 0.0000657 (50 iterations in 1.159s)
# [t-SNE] Iteration 850: error = 1.2977340, gradient norm = 0.0000614 (50 iterations in 1.099s)
# [t-SNE] Iteration 900: error = 1.2919480, gradient norm = 0.0000580 (50 iterations in 1.162s)
# [t-SNE] Iteration 950: error = 1.2869815, gradient norm = 0.0000538 (50 iterations in 1.119s)
# [t-SNE] Iteration 1000: error = 1.2825557, gradient norm = 0.0000523 (50 iterations in 1.161s)
# [t-SNE] KL divergence after 1000 iterations: 1.282556
# Done..
# Creating plot for this t-sne visualization..
# saving this plot as image in present working directory...
# Done

# %% [markdown]
# # Prediction Model

# %%
train = pd.read_csv('UCI_HAR_dataset/csv_files/train.csv')
test = pd.read_csv('UCI_HAR_dataset/csv_files/test.csv')
print(train.shape, test.shape)
# Out:
# (7352, 564) (2947, 564)

# %%
train.head(2)
# Out:
#    tBodyAccmeanX  tBodyAccmeanY  tBodyAccmeanZ  tBodyAccstdX  tBodyAccstdY  \
# 0       0.288585      -0.020294      -0.132905     -0.995279     -0.983111
# 1       0.278419      -0.016411      -0.123520     -0.998245     -0.975300
#
#    tBodyAccstdZ  tBodyAccmadX  tBodyAccmadY  tBodyAccmadZ  tBodyAccmaxX  ...  \
# 0     -0.913526     -0.995112     -0.983185     -0.923527     -0.934724  ...
# 1     -0.960322     -0.998807     -0.974914     -0.957686     -0.943068  ...
#
#    angletBodyAccMeangravity  angletBodyAccJerkMeangravityMean  \
# 0                 -0.112754                          0.030400
# 1                  0.053477                         -0.007435
#
#    angletBodyGyroMeangravityMean  angletBodyGyroJerkMeangravityMean  \
# 0                      -0.464761                          -0.018446
# 1                      -0.732626                           0.703511
#
#    angleXgravityMean  angleYgravityMean  angleZgravityMean  subject  Activity  \
# 0          -0.841247           0.179941          -0.058627        1         5
# 1          -0.844788           0.180289          -0.054317        1         5
#
#    ActivityName
# 0      STANDING
# 1      STANDING
#
# [2 rows x 564 columns]

# %%
# get X_train and y_train from csv files
X_train = train.drop(['subject', 'Activity', 'ActivityName'], axis=1)
y_train = train.ActivityName

# get X_test and y_test from test csv file
X_test = test.drop(['subject', 'Activity', 'ActivityName'], axis=1)
y_test = test.ActivityName

print('X_train and y_train : ({},{})'.format(X_train.shape, y_train.shape))
print('X_test  and y_test  : ({},{})'.format(X_test.shape, y_test.shape))
# Out:
# X_train and y_train : ((7352, 561),(7352,))
# X_test  and y_test  : ((2947, 561),(2947,))

# %%
labels=['LAYING', 'SITTING','STANDING','WALKING','WALKING_DOWNSTAIRS','WALKING_UPSTAIRS']

# %%
# Function to Plot Confusion Matrix

import itertools
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn import metrics
plt.rcParams["font.family"] = 'DejaVu Sans'

def plot_confusion_matrix(cm, classes,normalize=False,title='Confusion matrix',cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),horizontalalignment="center",color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %% [markdown]
# - Declaring A function to run any specified Model

# %%
from datetime import datetime
def perform_model(model, X_train, y_train, X_test, y_test, class_labels, cm_normalize=True,print_cm=True, cm_cmap=plt.cm.Greens):
    
    
    # to store results at various phases
    results = dict()
    
    # time at which model starts training 
    train_start_time = datetime.now()
    print('training the model..')
    model.fit(X_train, y_train)
    print('Done \n \n')
    train_end_time = datetime.now()
    results['training_time'] =  train_end_time - train_start_time
    print('training_time(HH:MM:SS.ms) - {}\n\n'.format(results['training_time']))
    
    
    # predict test data
    print('Predicting test data')
    test_start_time = datetime.now()
    y_pred = model.predict(X_test)
    test_end_time = datetime.now()
    print('Done \n \n')
    results['testing_time'] = test_end_time - test_start_time
    print('testing time(HH:MM:SS:ms) - {}\n\n'.format(results['testing_time']))
    results['predicted'] = y_pred
   

    # calculate overall accuracty of the model
    accuracy = accuracy_score(y_true=y_test, y_pred=y_pred)
    # store accuracy in results
    results['accuracy'] = accuracy
    print('---------------------')
    print('|      Accuracy      |')
    print('---------------------')
    print('\n    {}\n\n'.format(accuracy))
    
    
    # confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    results['confusion_matrix'] = cm
    if print_cm: 
        print('--------------------')
        print('| Confusion Matrix |')
        print('--------------------')
        print('\n {}'.format(cm))
        
    # plot confusin matrix
    plt.figure(figsize=(8,8))
    plt.grid(b=False)
    plot_confusion_matrix(cm, classes=class_labels, normalize=True, title='Normalized confusion matrix', cmap = cm_cmap)
    plt.show()
    
    # get classification report
    print('-------------------------')
    print('| Classifiction Report |')
    print('-------------------------')
    classification_report = metrics.classification_report(y_test, y_pred)
    # store report in results
    results['classification_report'] = classification_report
    print(classification_report)
    
    # add the trained  model to the results
    results['model'] = model
    
    return results

# %%
def print_grid_search_attributes(model):
    # Estimator that gave highest score among all the estimators formed in GridSearch
    print('--------------------------')
    print('|      Best Estimator     |')
    print('--------------------------')
    print('\n\t{}\n'.format(model.best_estimator_))


    # parameters that gave best results while performing grid search
    print('--------------------------')
    print('|     Best parameters     |')
    print('--------------------------')
    print('\tParameters of best estimator : \n\n\t{}\n'.format(model.best_params_))


    #  number of cross validation splits
    print('---------------------------------')
    print('|   No of CrossValidation sets   |')
    print('--------------------------------')
    print('\n\tTotal numbre of cross validation sets: {}\n'.format(model.n_splits_))


    # Average cross validated score of the best estimator, from the Grid Search 
    print('--------------------------')
    print('|        Best Score       |')
    print('--------------------------')
    print('\n\tAverage Cross Validate scores of best estimator : \n\n\t{}\n'.format(model.best_score_))

# %% [markdown]
# # 1. Logistic Regression with Grid Search

# %%
from sklearn import linear_model
from sklearn import metrics
from sklearn.model_selection import GridSearchCV

# %%
# start Grid search
parameters = {'C':[0.01, 0.1, 1, 10, 20, 30], 'penalty':['l2','l1']}
log_reg = linear_model.LogisticRegression()
log_reg_grid = GridSearchCV(log_reg, param_grid=parameters, cv=3, verbose=1, n_jobs=-1)
log_reg_grid_results =  perform_model(log_reg_grid, X_train, y_train, X_test, y_test, class_labels=labels)
# Out:
# training the model..
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# Done
#
#
# training_time(HH:MM:SS.ms) - 0:00:12.417401
#
#
# Predicting test data
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:00.010008
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.9586019681031558
#
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[537   0   0   0   0   0]
#  [  0 430  58   0   0   3]
#  [  0  15 517   0   0   0]
#  [  0   0   0 493   2   1]
#  [  0   0   0   4 403  13]
#  [  0   0   0  25   1 445]]
# -------------------------
# | Classifiction Report |
# -------------------------
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.97      0.88      0.92       491
#           STANDING       0.90      0.97      0.93       532
#            WALKING       0.94      0.99      0.97       496
# WALKING_DOWNSTAIRS       0.99      0.96      0.98       420
#   WALKING_UPSTAIRS       0.96      0.94      0.95       471
#
#           accuracy                           0.96      2947
#          macro avg       0.96      0.96      0.96      2947
#       weighted avg       0.96      0.96      0.96      2947

# %%
plt.figure(figsize=(8,8))
plt.grid(b=False)
plot_confusion_matrix(log_reg_grid_results['confusion_matrix'], classes=labels, cmap=plt.cm.Greens, )
plt.show()

# %%
# observe the attributes of the model 
print_grid_search_attributes(log_reg_grid_results['model'])
# Out:
# --------------------------
# |      Best Estimator     |
# --------------------------
#
# 	LogisticRegression(C=1)
#
# --------------------------
# |     Best parameters     |
# --------------------------
# 	Parameters of best estimator :
#
# 	{'C': 1, 'penalty': 'l2'}
#
# ---------------------------------
# |   No of CrossValidation sets   |
# --------------------------------
#
# 	Total numbre of cross validation sets: 3
#
# --------------------------
# |        Best Score       |
# --------------------------
#
# 	Average Cross Validate scores of best estimator :
#
# 	0.9371615639319785

# %% [markdown]
# # 2. Linear SVC with GridSearch

# %%
from sklearn.svm import LinearSVC

# %%
parameters = {'C':[0.125, 0.5, 1, 2, 8, 16]}
lr_svc = LinearSVC(tol=0.00005)
lr_svc_grid = GridSearchCV(lr_svc, param_grid=parameters, n_jobs=-1, verbose=1)
lr_svc_grid_results = perform_model(lr_svc_grid, X_train, y_train, X_test, y_test, class_labels=labels)
# Out:
# training the model..
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Done
#
#
# training_time(HH:MM:SS.ms) - 0:00:38.378157
#
#
# Predicting test data
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:00.011014
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.9667458432304038
#
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[537   0   0   0   0   0]
#  [  2 428  58   0   0   3]
#  [  0   9 522   1   0   0]
#  [  0   0   0 496   0   0]
#  [  0   0   0   3 412   5]
#  [  0   0   0  17   0 454]]
# -------------------------
# | Classifiction Report |
# -------------------------
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.98      0.87      0.92       491
#           STANDING       0.90      0.98      0.94       532
#            WALKING       0.96      1.00      0.98       496
# WALKING_DOWNSTAIRS       1.00      0.98      0.99       420
#   WALKING_UPSTAIRS       0.98      0.96      0.97       471
#
#           accuracy                           0.97      2947
#          macro avg       0.97      0.97      0.97      2947
#       weighted avg       0.97      0.97      0.97      2947

# %%
print_grid_search_attributes(lr_svc_grid_results['model'])
# Out:
# --------------------------
# |      Best Estimator     |
# --------------------------
#
# 	LinearSVC(C=0.5, tol=5e-05)
#
# --------------------------
# |     Best parameters     |
# --------------------------
# 	Parameters of best estimator :
#
# 	{'C': 0.5}
#
# ---------------------------------
# |   No of CrossValidation sets   |
# --------------------------------
#
# 	Total numbre of cross validation sets: 5
#
# --------------------------
# |        Best Score       |
# --------------------------
#
# 	Average Cross Validate scores of best estimator :
#
# 	0.9426083417731471

# %% [markdown]
# # 3. Kernel SVM with GridSearch

# %%
from sklearn.svm import SVC

parameters = {'C':[2,8,16],'gamma': [ 0.0078125, 0.125, 2]}
rbf_svm = SVC(kernel='rbf')
rbf_svm_grid = GridSearchCV(rbf_svm,param_grid=parameters, n_jobs=-1)
rbf_svm_grid_results = perform_model(rbf_svm_grid, X_train, y_train, X_test, y_test, class_labels=labels)
# Out:
# training the model..
# Done
#
#
# training_time(HH:MM:SS.ms) - 0:04:26.170271
#
#
# Predicting test data
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:01.099002
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.9626739056667798
#
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[537   0   0   0   0   0]
#  [  0 441  48   0   0   2]
#  [  0  12 520   0   0   0]
#  [  0   0   0 489   2   5]
#  [  0   0   0   4 397  19]
#  [  0   0   0  17   1 453]]
# -------------------------
# | Classifiction Report |
# -------------------------
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.97      0.90      0.93       491
#           STANDING       0.92      0.98      0.95       532
#            WALKING       0.96      0.99      0.97       496
# WALKING_DOWNSTAIRS       0.99      0.95      0.97       420
#   WALKING_UPSTAIRS       0.95      0.96      0.95       471
#
#           accuracy                           0.96      2947
#          macro avg       0.96      0.96      0.96      2947
#       weighted avg       0.96      0.96      0.96      2947

# %%
print_grid_search_attributes(rbf_svm_grid_results['model'])
# Out:
# --------------------------
# |      Best Estimator     |
# --------------------------
#
# 	SVC(C=16, gamma=0.0078125)
#
# --------------------------
# |     Best parameters     |
# --------------------------
# 	Parameters of best estimator :
#
# 	{'C': 16, 'gamma': 0.0078125}
#
# ---------------------------------
# |   No of CrossValidation sets   |
# --------------------------------
#
# 	Total numbre of cross validation sets: 5
#
# --------------------------
# |        Best Score       |
# --------------------------
#
# 	Average Cross Validate scores of best estimator :
#
# 	0.9447834551903698

# %% [markdown]
# # 4. Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
params = {'n_estimators': np.arange(10,201,20), 'max_depth':np.arange(3,15,2)}
rfc = RandomForestClassifier()
rfc_grid = GridSearchCV(rfc, param_grid=params, n_jobs=-1)
rfc_grid_results = perform_model(rfc_grid, X_train, y_train, X_test, y_test, class_labels=labels)
print_grid_search_attributes(rfc_grid_results['model'])
# Out:
# training the model..
# Done
#
#
# training_time(HH:MM:SS.ms) - 0:03:29.223067
#
#
# Predicting test data
# Done
#
#
# testing time(HH:MM:SS:ms) - 0:00:00.075069
#
#
# ---------------------
# |      Accuracy      |
# ---------------------
#
#     0.9222938581608415
#
#
# --------------------
# | Confusion Matrix |
# --------------------
#
#  [[537   0   0   0   0   0]
#  [  0 433  58   0   0   0]
#  [  0  46 486   0   0   0]
#  [  0   0   0 478   8  10]
#  [  0   0   0  25 351  44]
#  [  0   0   0  31   7 433]]
# -------------------------
# | Classifiction Report |
# -------------------------
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       537
#            SITTING       0.90      0.88      0.89       491
#           STANDING       0.89      0.91      0.90       532
#            WALKING       0.90      0.96      0.93       496
# WALKING_DOWNSTAIRS       0.96      0.84      0.89       420
#   WALKING_UPSTAIRS       0.89      0.92      0.90       471
#
#           accuracy                           0.92      2947
#          macro avg       0.92      0.92      0.92      2947
#       weighted avg       0.92      0.92      0.92      2947
#
# --------------------------
# |      Best Estimator     |
# --------------------------
#
# 	RandomForestClassifier(max_depth=11, n_estimators=170)
#
# --------------------------
# |     Best parameters     |
# --------------------------
# 	Parameters of best estimator :
#
# 	{'max_depth': 11, 'n_estimators': 170}
#
# ---------------------------------
# |   No of CrossValidation sets   |
# --------------------------------
#
# 	Total numbre of cross validation sets: 5
#
# --------------------------
# |        Best Score       |
# --------------------------
#
# 	Average Cross Validate scores of best estimator :
#
# 	0.9236985344783732

# %% [markdown]
# # LSTM on RAW Data signals

# %%
# Data directory
DATADIR = 'UCI_HAR_Dataset'

# Raw data signals
# Signals are from Accelerometer and Gyroscope
# The signals are in x,y,z directions
# Sensor signals are filtered to have only body acceleration
# excluding the acceleration due to gravity
# Triaxial acceleration from the accelerometer is total acceleration
SIGNALS = [
    "body_acc_x",
    "body_acc_y",
    "body_acc_z",
    "body_gyro_x",
    "body_gyro_y",
    "body_gyro_z",
    "total_acc_x",
    "total_acc_y",
    "total_acc_z"
]

# %%
# Utility function to read the data from csv file
def _read_csv(filename):
    return pd.read_csv(filename, delim_whitespace=True, header=None)

# Utility function to load the load
def load_signals(subset):
    signals_data = []

    for signal in SIGNALS:
        filename = f'UCI_HAR_Dataset/{subset}/Inertial Signals/{signal}_{subset}.txt'
        signals_data.append(_read_csv(filename).values) 

    # Transpose is used to change the dimensionality of the output,
    # aggregating the signals by combination of sample/timestep.
    # Resultant shape is (7352 train/2947 test samples, 128 timesteps, 9 signals)
    return np.transpose(signals_data, (1, 2, 0))

# %%
def load_y(subset):
    filename = f'UCI_HAR_Dataset/{subset}/y_{subset}.txt'
    y = _read_csv(filename)[0]
    return pd.get_dummies(y).values

# %%
def load_data():
    X_train, X_test = load_signals('train'), load_signals('test')
    y_train, y_test = load_y('train'), load_y('test')
    return X_train, X_test, y_train, y_test

# %%
# Importing libraries
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense, Dropout

# %%
# Utility function to count the number of classes
def _count_classes(y):
    return len(set([tuple(category) for category in y]))

# %%
# Loading the train and test data
X_train, X_test, Y_train, Y_test = load_data()

# %%
timesteps = len(X_train[0])
input_dim = len(X_train[0][0])
n_classes = _count_classes(Y_train)

print(timesteps)
print(input_dim)
print(len(X_train))
# Out:
# 128
# 9
# 7352

# %% [markdown]
# - Defining architecture of LSTM Model

# %%
# Initiliazing the sequential model
model = Sequential()
# Configuring the parameters
model.add(LSTM(32, input_shape=(timesteps, input_dim)))
# Adding a dropout layer
model.add(Dropout(0.5))
# Adding a dense output layer with sigmoid activation
model.add(Dense(n_classes, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 32)                5376
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense (Dense)               (None, 6)                 198
#
# =================================================================
# Total params: 5,574
# Trainable params: 5,574
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the model
model.compile(loss='categorical_crossentropy',optimizer='rmsprop',metrics=['accuracy'])
# Training the model
model.fit(X_train,Y_train,batch_size=16,validation_data=(X_test, Y_test),epochs=35)
# Out:
# Epoch 1/35
# 460/460 [==============================] - 10s 11ms/step - loss: 1.1059 - accuracy: 0.5307 - val_loss: 0.8303 - val_accuracy: 0.6227
# Epoch 2/35
# 460/460 [==============================] - 4s 9ms/step - loss: 0.7536 - accuracy: 0.6590 - val_loss: 0.7107 - val_accuracy: 0.6990
# Epoch 3/35
# 460/460 [==============================] - 4s 9ms/step - loss: 0.6390 - accuracy: 0.7334 - val_loss: 0.6358 - val_accuracy: 0.7747
# Epoch 4/35
# 460/460 [==============================] - 4s 9ms/step - loss: 0.4959 - accuracy: 0.8361 - val_loss: 0.5898 - val_accuracy: 0.7886
# Epoch 5/35
# 460/460 [==============================] - 4s 9ms/step - loss: 0.3931 - accuracy: 0.8814 - val_loss: 0.5111 - val_accuracy: 0.8331
# Epoch 6/35
# 460/460 [==============================] - 4s 9ms/step - loss: 0.3268 - accuracy: 0.9010 - val_loss: 0.4521 - val_accuracy: 0.8595
# Epoch 7/35
# 460/460 [==============================] - 4s 10ms/step - loss: 0.2655 - accuracy: 0.9203 - val_loss: 0.3460 - val_accuracy: 0.8911
# Epoch 8/35
# 460/460 [==============================] - 5s 10ms/step - loss: 0.2359 - accuracy: 0.9244 - val_loss: 0.3561 - val_accuracy: 0.8870
# Epoch 9/35
# 460/460 [==============================] - 4s 9ms/step - loss: 0.2045 - accuracy: 0.9321 - val_loss: 0.3336 - val_accuracy: 0.8928
# Epoch 10/35
# 460/460 [==============================] - 4s 9ms/step - loss: 0.1968 - accuracy: 0.9351 - val_loss: 0.5705 - val_accuracy: 0.8395
# Epoch 11/35
# 460/460 [==============================] - 4s 9ms/step - loss: 0.1974 - accuracy: 0.9393 - val_loss: 0.3071 - val_accuracy: 0.8996
# Epoch 12/35
# 460/460 [==============================] - 4s 9ms/step - loss: 0.2030 - accuracy: 0.9353 - val_loss: 0.3322 - val_accuracy: 0.8999
# Epoch 13/35
# 460/460 [==============================] - 4s 9ms/step - loss: 0.1844 - accuracy: 0.9355 - val_loss: 0.3558 - val_accuracy: 0.8941
# Epoch 14/35
# 460/460 [==============================] - 4s 9ms/step - loss: 0.1727 - accuracy: 0.9411 - val_loss: 0.3473 - val_accuracy: 0.8887
# Epoch 15/35
# 460/460 [==============================] - 4s 9ms/step - loss: 0.1631 - accuracy: 0.9411 - val_loss: 0.4704 - val_accuracy: 0.8724
# Epoch 16/35
# 460/460 [==============================] - 4s 9ms/step - loss: 0.1703 - accuracy: 0.9404 - val_loss: 0.6380 - val_accuracy: 0.8521
# Epoch 17/35
# 460/460 [==============================] - 4s 9ms/step - loss: 0.1794 - accuracy: 0.9416 - val_loss: 0.4134 - val_accuracy: 0.8965
# Epoch 18/35
# 460/460 [==============================] - 4s 9ms/step - loss: 0.1616 - accuracy: 0.9418 - val_loss: 0.4795 - val_accuracy: 0.8965
# Epoch 19/35
# 460/460 [==============================] - 4s 9ms/step - loss: 0.1588 - accuracy: 0.9431 - val_loss: 0.3114 - val_accuracy: 0.9080
# Epoch 20/35
# 460/460 [==============================] - 4s 9ms/step - loss: 0.1543 - accuracy: 0.9459 - val_loss: 0.3985 - val_accuracy: 0.9077
# Epoch 21/35
# 460/460 [==============================] - 4s 9ms/step - loss: 0.1583 - accuracy: 0.9440 - val_loss: 0.3332 - val_accuracy: 0.9131
# Epoch 22/35
# 460/460 [==============================] - 4s 9ms/step - loss: 0.1666 - accuracy: 0.9423 - val_loss: 0.4089 - val_accuracy: 0.8904
# Epoch 23/35
# 460/460 [==============================] - 4s 9ms/step - loss: 0.1487 - accuracy: 0.9441 - val_loss: 0.2964 - val_accuracy: 0.9087
# Epoch 24/35
# 460/460 [==============================] - 4s 9ms/step - loss: 0.1406 - accuracy: 0.9480 - val_loss: 0.3740 - val_accuracy: 0.9104
# Epoch 25/35
# 460/460 [==============================] - 4s 9ms/step - loss: 0.1377 - accuracy: 0.9513 - val_loss: 0.4626 - val_accuracy: 0.9063
# Epoch 26/35
# 460/460 [==============================] - 4s 9ms/step - loss: 0.1347 - accuracy: 0.9491 - val_loss: 0.3307 - val_accuracy: 0.9084
# Epoch 27/35
# 460/460 [==============================] - 4s 9ms/step - loss: 0.1605 - accuracy: 0.9449 - val_loss: 0.4320 - val_accuracy: 0.9080
# Epoch 28/35
# 460/460 [==============================] - 4s 9ms/step - loss: 0.1412 - accuracy: 0.9486 - val_loss: 0.3511 - val_accuracy: 0.9114
# Epoch 29/35
# 460/460 [==============================] - 4s 9ms/step - loss: 0.1394 - accuracy: 0.9480 - val_loss: 0.4439 - val_accuracy: 0.9057
# Epoch 30/35
# 460/460 [==============================] - 4s 9ms/step - loss: 0.1309 - accuracy: 0.9528 - val_loss: 0.3338 - val_accuracy: 0.9158
# Epoch 31/35
# 460/460 [==============================] - 4s 9ms/step - loss: 0.1313 - accuracy: 0.9512 - val_loss: 0.4939 - val_accuracy: 0.8941
# Epoch 32/35
# 460/460 [==============================] - 4s 9ms/step - loss: 0.1569 - accuracy: 0.9479 - val_loss: 0.4556 - val_accuracy: 0.9094
# Epoch 33/35
# 460/460 [==============================] - 4s 9ms/step - loss: 0.1368 - accuracy: 0.9478 - val_loss: 0.5242 - val_accuracy: 0.9046
# Epoch 34/35
# 460/460 [==============================] - 4s 9ms/step - loss: 0.1329 - accuracy: 0.9536 - val_loss: 0.4454 - val_accuracy: 0.9077
# Epoch 35/35
# 460/460 [==============================] - 4s 9ms/step - loss: 0.1495 - accuracy: 0.9480 - val_loss: 0.4064 - val_accuracy: 0.9094

# %%
score = model.evaluate(X_test, Y_test)
# Out:
# 93/93 [==============================] - 1s 7ms/step - loss: 0.4064 - accuracy: 0.9094

# %%
print(score)
# Out:
# [0.40644803643226624, 0.9093993902206421]

# %% [markdown]
# - By using the RAW data and Applying LSTM we are getting accuracy of 90% which is great still not better than the SVM & Linear models but here we only passed the RAW data whereas in the Classical ML models we have used Featured Data for which special domain knowledge is required.
